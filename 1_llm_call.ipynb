# %%
from langchain_anthropic import ChatAnthropic
from dotenv import load_dotenv
from pathlib import Path

result = load_dotenv(dotenv_path=Path(".env"))
print(result)

# %%
import os
if os.getenv("ANTHROPIC_API_KEY") is None:
    raise ValueError("ANTHROPIC_API_KEY environment variable not set")
else:
    print("ANTHROPIC_API_KEY environment variable set")
# Out:
# ANTHROPIC_API_KEY environment variable set

# %%
llm = ChatAnthropic(model="claude-haiku-4-5-20251001")

response = llm.invoke("Give me the code to create a pandas dataframe with 3 columns and 5 rows")
response.content
# Out:
# "# Create a simple pandas DataFrame with 3 columns and 5 rows\n\n```python\nimport pandas as pd\n\ndf = pd.DataFrame({\n    'Column1': [1, 2, 3, 4, 5],\n    'Column2': ['A', 'B', 'C', 'D', 'E'],\n    'Column3': [10.5, 20.3, 15.7, 25.1, 18.9]\n})\n\nprint(df)\n```\n\n**Output:**\n```\n   Column1 Column2  Column3\n0        1       A     10.5\n1        2       B     20.3\n2        3       C     15.7\n3        4       D     25.1\n4        5       E     18.9\n```\n\n---\n\n### Alternative methods:\n\n**Using a list of lists:**\n```python\ndf = pd.DataFrame([\n    [1, 'A', 10.5],\n    [2, 'B', 20.3],\n    [3, 'C', 15.7],\n    [4, 'D', 25.1],\n    [5, 'E', 18.9]\n], columns=['Column1', 'Column2', 'Column3'])\n```\n\n**Using random data:**\n```python\nimport numpy as np\n\ndf = pd.DataFrame(np.random.randn(5, 3), columns=['Col1', 'Col2', 'Col3'])\n```"
